# %%
# https://open.kattis.com/problems/tarifa

X = int(input())
N = int(input())

som = X*(N+1)
for _ in range(N):
    som -= int(input())
    
print(som)
# Out:
# 15
# 3
# 15
# 10
# 20
# 15

# %%
som
# Out:
# 16
